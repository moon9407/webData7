# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup
import time
import os
import random
from selenium.webdriver.chrome.options import Options

options = Options()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument("--disable-blink-features=AutomationControlled")

# %%
browser = webdriver.Chrome(options=options) # 창열기
browser.maximize_window() # 최대창 확대
for i in range(1,6):
    url = f"https://www.auction.co.kr/n/search?keyword=tv&k=54&p={i}"
browser.get(url)

# %%
soup = BeautifulSoup(browser.page_source,"lxml")
body = soup.find("div",{"id":"region__content-body"})
print(body)
# wraps = soup.find("div",{"class":"section__module-wrap"})
# print(wraps)
# section = wraps.find_all("div",{"class":"box__component"})
# print(section)
# item = section.find_all("div",{"class":"box__item-container"})
# print(item)
# img = imgbox.find("img")['src']
# title = wraps.find("div",{"class":"box__item-title"}).find("span",{"class":"text__item"}).text.strip()
# print(title)
# price = wraps.find("div",{"class":"box__price-seller"}).find("strong",{"class":"text text__value"}).text.strip()
# scorebox = wraps.find("div",{"class":"box__information-score"})
# score = scorebox.find("span",{"class":"for-a11y"}).text.strip()
# feedback = scorebox.find("span",{"class":"text"}).text[1:-1]
# print(feedback)
# Out:
# <div id="region__content-body"><h3 class="for-a11y">검색 결과 컨텐츠</h3><div id="section__inner-content-body-container"><div class="section__module-wrap module-exp-spm-c" data-aplus-ae="x1_6030d89f" data-eltype="spmc" data-params-exp="gmkt_page_id=&amp;gmkt_area_code=&amp;section_index=&amp;module_index=0&amp;ab_buckets=" data-spm="prime" data-spm-anchor-id="gmktpc.searchlist.0.prime.6feb3e35EBWNIV" data-spm-max-idx="16" spmc="prime"><div class="box__component box__component-capsule-slot"><h4 class="text--module_title">광고 상품 목록</h4><div class="box__tier-container"><div class="box__tier-gap-fake"></div><p class="text__title">오늘의 프라임상품</p><div class="box__advertisement-container"><button aria-controls="box__titleTierTooltip0" aria-expanded="false" aria-haspopup="true" class="button__notice-about-advertisement" title="광고 안내 레이어 보기" type="button"><span class="text">광고</span></button><div class="box__layer-information" id="box__titleTierTooltip0"><p class="text__information-description">노출보장형 키
# ...
